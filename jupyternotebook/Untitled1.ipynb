# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the CSV file using 'latin-1' encoding
df = pd.read_csv('demo.csv', index_col='FIR_No', parse_dates=True, encoding='latin-1')

# Set the frequency of the index to 'MS' (Month Start)
df.index.freq = 'MS'
# Out:
# C:\Users\tathe\AppData\Local\Temp\ipykernel_14100\2991257003.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('demo.csv', index_col='FIR_No', parse_dates=True, encoding='latin-1')

# %%
df.head(5)
# Out:
#        First_Name Last_Name  Age Date_of_Birth     Aadhar_No  Gender  \
# FIR_No
# 97          JASON   MEADOWS   77    10-11-2017  2.987800e+11    MALE
# 98         WALTER   JACKSON   23    16-07-1962  2.420440e+11    MALE
# 99         STACEY    THOMAS   48    09-11-1957  6.187840e+11  FEMALE
# 100       DEBORAH    KRAMER   18    03-05-2020  7.578150e+11  FEMALE
# 101          LISA    MILLER   45    09-08-1998  3.447350e+11    MALE
#
#           Phone_No  Height                                            Address  \
# FIR_No
# 97      7751476698     160     287 SALLY MOUNT\r\nLAKE BENJAMINSTAD, TX 82175
# 98      2755543583     156            14927 COLLINS RUN\r\nNEW KARI, IN 21271
# 99      3511257572     163  66090 SMITH EXTENSIONS APT. 233\r\nRYANPORT, M...
# 100     8444118454     189  56438 JOSHUA RAMP\r\nWEST VALERIEBOROUGH, AZ 8...
# 101     2243447888     195         912 MICHAEL PLAIN\r\nSOUTH DIANE, MN 27769
#
#        Type_of_Crime  ...             Discription_of_Vehicle  \
# ...

# %%
df.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='FIR_No'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

import statsmodels.api as sm

# %%
# results = seasonal_decompose(df['Pincode'])

# Assuming your DataFrame 'df' has a 'Pincode' column with timestamps or periods
results = sm.tsa.seasonal_decompose(df['Pincode'], period=7)  # Replace 7 with appropriate frequency

# %%
results.plot()

# %%
len(df)
# Out:
# 55

# %%
train = df.iloc[:45]
test = df.iloc[45:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df.head()
# Out:
#        First_Name Last_Name  Age Date_of_Birth     Aadhar_No  Gender  \
# FIR_No
# 97          JASON   MEADOWS   77    10-11-2017  2.987800e+11    MALE
# 98         WALTER   JACKSON   23    16-07-1962  2.420440e+11    MALE
# 99         STACEY    THOMAS   48    09-11-1957  6.187840e+11  FEMALE
# 100       DEBORAH    KRAMER   18    03-05-2020  7.578150e+11  FEMALE
# 101          LISA    MILLER   45    09-08-1998  3.447350e+11    MALE
#
#           Phone_No  Height                                            Address  \
# FIR_No
# 97      7751476698     160     287 SALLY MOUNT\r\nLAKE BENJAMINSTAD, TX 82175
# 98      2755543583     156            14927 COLLINS RUN\r\nNEW KARI, IN 21271
# 99      3511257572     163  66090 SMITH EXTENSIONS APT. 233\r\nRYANPORT, M...
# 100     8444118454     189  56438 JOSHUA RAMP\r\nWEST VALERIEBOROUGH, AZ 8...
# 101     2243447888     195         912 MICHAEL PLAIN\r\nSOUTH DIANE, MN 27769
#
#        Type_of_Crime  ...             Discription_of_Vehicle  \
# ...

# %%
df.tail()
# Out:
#        First_Name  Last_Name  Age Date_of_Birth     Aadhar_No  Gender  \
# FIR_No
# 147        DARREN  GUTIERREZ   72    23-12-1920  7.160080e+11    MALE
# 148       KENNETH    JOHNSON   65    22-07-1966  2.885340e+11  FEMALE
# 149        DEANNA     THOMAS   28    30-01-1941  4.829840e+11  FEMALE
# 150        DANIEL   LAWRENCE   48    13-07-1943  3.967970e+11    MALE
# 151         FRANK    PATRICK   93    23-11-1908  7.504010e+11  FEMALE
#
#           Phone_No  Height                                            Address  \
# FIR_No
# 147     6102414895     178           1319 ANDREW RIDGE\r\nWEST JOHN, AS 36506
# 148     3510800499     179  17138 GLORIA VISTA APT. 557\r\nSOUTH KEVIN, NV...
# 149     8532450256     170                 PSC 4727, BOX 4480\r\nAPO AP 33540
# 150     3819321072     167       23990 DAVIS GARDEN\r\nGOMEZBOROUGH, OK 90629
# 151     3441922779     199  252 GALLOWAY SUMMIT APT. 845\r\nANDERSONBOROUG...
#
# ...

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14100\1974102410.py in ?()
# ----> 1 scaler.fit(train)
#       2 scaled_train = scaler.transform(train)
#       3 scaled_test = scaler.transform(test)
#
# c:\users\tathe\appdata\local\programs\python\python39\lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, y)
#     430             Fitted scaler.
#     431         """
#     432         # Reset internal state before fitting
#     433         self._reset()
# --> 434         return self.partial_fit(X, y)
#
# c:\users\tathe\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# ...
